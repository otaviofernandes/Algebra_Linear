# %% [markdown]
# <a href="https://colab.research.google.com/github/otaviofernandes/Algebra_Linear/blob/main/AC2_Algebra_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**ÁLGEBRA LINEAR**
#
# Prof. Alex Carneiro
#
# #**AC2 - Cônicas**
#
#
#
#
# **Equipe**:
#
# Deborah Yamazaki Hukuda.............RA: 1905373
#
# Flávia Tamie Hajime........................RA: 1905355
#
# Gabriel da Silva Lima.......................RA: 1905064
#
# Otavio de Almeida Fernandes.........RA: 1901796
#
# Vinicius Veloso dos Santos.............RA: 1905107

# %% [markdown]
# **EXERCÍCIO 1**

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

#variável de apoio para círculos
t = np.linspace(0, 2*np.pi, 100)

#circulo 1 - cabeça
r1 = 50
xc1, yc1 = 0, 0
x1 = r1 * np.cos(t) + xc1
y1 = r1 * np.sin(t) + yc1

#circulo 2 - nariz
r2 = 10
xc2, yc2 = 0, 0
x2 = r2 * np.cos(t) + xc2
y2 = r2 * np.sin(t) + yc2

#parábola 1 - boca
t1 = np.linspace(-40, 40, 100)
a1 = 0.02
xv1, yv1 = 0,-25
x3 = t1
y3 = a1*(t1 - xv1)**2 + yv1

#parábola 2 - boca
t2 = np.linspace(-40, 40, 100)
a2 = 0.03
xv2, yv2 = 0,-41
x4 = t2
y4 = a2*(t2 - xv2)**2 + yv2

#parábola 3 - boca
t3 = np.linspace(-10, 10, 100)
a3 = -0.09
xv3, yv3 = 0,-29
x5 = t3
y5 = a3*(t3 - xv3)**2 + yv3

#reta 1 - chapeu
t4 = np.linspace(0, 30, 100)
x6 = t4
y6 = t4 + 50

#reta 2 - chapeu
t5 = np.linspace(30, 40, 100)
x7 = t5
y7 = -5*t5 + 230

# hipérbole - olhos
t6 = np.linspace(-3, 3, 100)
a4 = 3
b4 = 1
xc3, yc3 = 0, 20
x8 = a4*np.cosh(t6) + xc3
y8 = b4*np.sinh(t6) + yc3

#plotagem do gráfico
plt.figure(figsize=(9.35, 11.9))
plt.title('Gráfico - Exercício 1')
plt.xticks(np.linspace(-40, 40, 5))
plt.yticks(np.linspace(-40, 80, 7))
plt.xlim(-55, 55)
plt.ylim(-55, 85)
plt.plot(x1, y1, 'blue');
plt.plot(x2, y2, 'blue');
plt.plot(x3, y3, 'blue');
plt.plot(x4, y4, 'blue');
plt.plot(x5, y5, 'blue');
plt.plot(x6, y6, 'blue');
plt.plot(x7, y7, 'blue');
plt.plot(x8, y8, 'blue')
plt.plot(xc3 - x8, y8, 'blue');

# %% [markdown]
# **EXERCÍCIO 2**

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

#variável de apoio para círculos e elipses
t = np.linspace(0, 2*np.pi, 100)

#circulo 1 - cabeça
r1 = 50
xc1, yc1 = 0, 0
x1 = r1 * np.cos(t) + xc1
y1 = r1 * np.sin(t) + yc1

#circulo 2 - orelha esquerda
r2 = 22
xc2, yc2 = -60, 40
x2 = r2 * np.cos(t) + xc2
y2 = r2 * np.sin(t) + yc2

#circulo 3  - orelha direita
r3 = 22
xc3, yc3 = 60, 40
x3 = r3 * np.cos(t) + xc3
y3 = r3 * np.sin(t) + yc3

#circulo 4  - olho esquerdo
r4 = 5
xc4, yc4 = -20, 10
x4 = r4 * np.cos(t) + xc4
y4 = r4 * np.sin(t) + yc4

#circulo 5  - olho direito
r5 = 5
xc5, yc5 = 20, 10
x5 = r5 * np.cos(t) + xc5
y5 = r5 * np.sin(t) + yc5

#elipse horizontal - nariz
a1 = 8
b1 = 4
xc6, yc6 = 0, -5
x6 = a1*np.cos(t) + xc6
y6 = b1*np.sin(t) + yc6

#elipse vertical 1 - olho esquerdo
a2 = 17
b2 = 8
xc7, yc7 = -20, 15
x7 = b2*np.cos(t) + xc7
y7 = a2*np.sin(t) + yc7

#elipse vertical 2 - olho direito
a3 = 17
b3 = 8
xc8, yc8 = 20, 15
x8 = b3*np.cos(t) + xc8
y8 = a3*np.sin(t) + yc8

#parábola 1 - boca
t1 = np.linspace(-40, 40,100)
a4 = 0.01
xv1, yv1 = 0,-25
x9 = t1
y9 = a4*(t1 - xv1)**2 + yv1

#parábola 2 - boca
t2 = np.linspace(-20, 20,100)
a5 = 0.035
xv2, yv2 = 0,-35
x10 = t2
y10 = a5*(t2 - xv2)**2 + yv2

#parábola 3 - boca
t3 = np.linspace(-20, 20,100)
a5 = -0.015
xv3, yv3 = 0, 0
x11 = t3
y11 = a5*(t3 - xv3)**2 + yv3

#plotagem do gráfico
plt.figure(figsize=(14.4, 10.8))
plt.title('Gráfico - Exercício 2')
plt.xticks(np.linspace(-80, 80, 9))
plt.yticks(np.linspace(-40, 60, 6))
plt.xlim(-85, 85)
plt.ylim(-55, 65)
plt.plot(x1, y1, 'black');
plt.plot(x2, y2, 'black');
plt.plot(x3, y3, 'black');
plt.plot(x4, y4, 'black');
plt.plot(x5, y5, 'black');
plt.plot(x6, y6, 'black');
plt.plot(x7, y7, 'black');
plt.plot(x8, y8, 'black');
plt.plot(x9, y9, 'black');
plt.plot(x10, y10, 'black');
plt.plot(x11, y11, 'black');

# %% [markdown]
# **EXERCÍCIO 3**

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# hipérbole 1 - bigodes
t1 = np.linspace(-3, 3, 100)
a1 = 3
b1 = 0.2
xc1, yc1 = 0, 0
x1 = a1*np.cosh(t1) + xc1
y1 = b1*np.sinh(t1) + yc1

# hipérbole 2 - bigodes
t2 = np.linspace(-3, 3, 100)
a2 = 3
b2 = 0.5
xc2, yc2 = 0, 0
x2 = a2*np.cosh(t2) + xc2
y2 = b2*np.sinh(t2) + yc2

# hipérbole 3 - bigodes
th = np.linspace(-3, 3, 100)
ah = 3
bh = 1
xch, ych = 0, 0
xh = ah*np.cosh(th) + xch
yh = bh*np.sinh(th) + ych


#circulo 1 - cabeça
t3 = np.linspace(0, 2*np.pi, 100)
r1 = 45
xc3, yc3 = 0, 15
x3 = r1 * np.cos(t3) + xc3
y3 = r1 * np.sin(t3) + yc3

#elipse horizontal - boca
t4 = np.linspace(0, 2*np.pi, 100)
a3 = 15
b3 = 7
xc4, yc4 = 0, -20
x4 = a3*np.sin(t4) + xc4
y4 = b3*np.cos(t4) + yc4

#elipse vertical 1 - olho esquerdo
t5 = np.linspace(0, 2*np.pi, 100)
a4 = 6
b4 = 0.5
xc5, yc5 = -10, 20
x5 = b4*np.cos(t5) + xc5
y5 = a4*np.sin(t5) + yc5

#circulo 2 - olho esquerdo
rcirc1 = 8
xcc1, ycc1 = 10, 20
xcirc1 = rcirc1 * np.cos(t3) + xcc1
ycirc1 = rcirc1 * np.sin(t3) + ycc1

#elipse vertical 2 - olho direito
t6 = np.linspace(0, 2*np.pi, 100)
a5 = 6
b5 = 0.5
xc6, yc6 = 10, 20
x6 = b5*np.cos(t6) + xc6
y6 = a5*np.sin(t6) + yc6

#circulo 2 - olho esquerdo
rcirc2 = 8
xcc2, ycc2 = -10, 20
xcirc2 = rcirc2 * np.cos(t3) + xcc2
ycirc2 = rcirc2 * np.sin(t3) + ycc2

#reta 1 - nariz
t7 = np.linspace(-5, 5, 100)
x7 = t7
y7 = 0*x7 + 5

#reta 1 - nariz
t8 = np.linspace(-5, 0, 100)
x8 = t8
y8 = -2*x8 - 5

#reta 2 - nariz
t9 = np.linspace(0, 5, 100)
x9 = t9
y9 = 2*x9 - 5

#reta 3 - orelha direita
t10 = np.linspace(10, 25, 100)
x10 = t10
y10 = 1.6*x10 + 43

#reta 4 - orelha direita
t11 = np.linspace(25, 40, 100)
x11 = t11
y11 = -3.1*t11 + 160

#reta 5 - orelha esquerda
t12 = np.linspace(-25, -10, 100)
x12 = t12
y12 = -1.6*x10 + 99

#reta 6 - orelha direita
t13 = np.linspace(-40, -25, 100)
x13 = t13
y13 = 3.11*t11 -42

#parábola 1 - sobrancelha
t14 = np.linspace(-20, 0, 100)
ap1 = -0.08
xv10, yv10 = -10, 40
x14 = t14
y14 = ap1*(t14 - xv10)**2 + yv10

#parábola 2 - sobrancelha
t15 = np.linspace(0, 20, 100)
ap2 = -0.08
xv11, yv11 = 10, 40
x15 = t15
y15 = ap2*(t15 - xv11)**2 + yv11

#plotagem do gráfico
plt.figure(figsize=(13.75, 17.5))
plt.title('Gráfico - Exercício 3')
plt.xticks(np.linspace(-40, 40, 5))
plt.yticks(np.linspace(-40, 80, 7))
plt.xlim(-55, 55)
plt.ylim(-45, 85)
plt.plot(x1, y1, 'black');
plt.plot(xc1 - x1, y1, 'black');
plt.plot(x2, y2, 'black');
plt.plot(xc2 - x2, y2, 'black');
plt.plot(xh, yh, 'black');
plt.plot(xch - xh, yh, 'black');
plt.plot(x3, y3, 'orange');
plt.plot(x4, y4, 'red');
plt.plot(x5, y5, 'black');
plt.plot(x6, y6, 'black');
plt.plot(x7, y7, 'black');
plt.plot(x8, y8, 'black');
plt.plot(x9, y9, 'black');
plt.plot(x10, y10, 'orange');
plt.plot(x11, y11, 'orange');
plt.plot(x12, y12, 'orange');
plt.plot(x13, y13, 'orange');
plt.plot(xcirc1, ycirc1, 'blue');
plt.plot(xcirc2, ycirc2, 'blue');
plt.plot(x14, y14, 'orange');
plt.plot(x15, y15, 'orange');

# %% [markdown]
# **REFERÊNCIA**
#
# .
#
# Código original disponível em: https://github.com/otaviofernandes/Algebra_Linear/blob/main/AC2_Algebra_Linear.ipynb
