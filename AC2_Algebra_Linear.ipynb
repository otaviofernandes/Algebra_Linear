# %% [markdown]
# <a href="https://colab.research.google.com/github/otaviofernandes/Algebra_Linear/blob/main/AC2_Algebra_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**ÁLGEBRA LINEAR**
#
# Prof. Alex Carneiro
#
# #**AC2 - Cônicas**
#
#
#
#
# **Equipe**:
#
# Deborah Yamazaki Hukuda.............RA: 1905373
#
# Flávia Tamie Hajime........................RA: 1905355
#
# Gabriel da Silva Lima.......................RA: 1905064
#
# Otavio de Almeida Fernandes.........RA: 1901796
#
# Vinicius Veloso dos Santos.............RA: 1905107

# %% [markdown]
# **EXERCÍCIO 1**

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

#circulo 1 - cabeça
t1 = np.linspace(0, 2*np.pi, 100)
r1 = 50
xc1, yc1 = 0, 0
x1 = r1 * np.cos(t1) + xc1
y1 = r1 * np.sin(t1) + yc1

#circulo 2 - nariz
t2 = np.linspace(0, 2*np.pi, 100)
r2 = 10
xc2, yc2 = 0, 0
x2 = r2 * np.cos(t2) + xc2
y2 = r2 * np.sin(t2) + yc2

#parábola 1 - boca
t3 = np.linspace(-40, 40, 100)
a3 = 0.02
xv3, yv3 = 0,-25
x3 = t3
y3 = a3 * (t3 - xv3) ** 2 + yv3

#parábola 2 - boca
t4 = np.linspace(-40, 40, 100)
a4 = 0.03
xv4, yv4 = 0,-41
x4 = t4
y4 = a4 * (t4 - xv4) ** 2 + yv4

#parábola 3 - boca
t5 = np.linspace(-10, 10, 100)
a5 = -0.09
xv5, yv5 = 0,-29
x5 = t5
y5 = a5 * (t5 - xv5) ** 2 + yv5

#semi-reta 1 - chapeu
t6 = np.linspace(0, 30, 100)
x6 = t6
y6 = t6 + 50

#semi-reta 2 - chapeu
t7 = np.linspace(30, 40, 100)
x7 = t7
y7 = -5 * t7 + 230

#hipérbole - olhos
t8 = np.linspace(-3, 3, 100)
a8 = 3
b8 = 1
xc8, yc8 = 0, 20
x8 = a8 * np.cosh(t8) + xc8
y8 = b8 * np.sinh(t8) + yc8

#plotagem do gráfico
plt.figure(figsize=(9.35, 11.9))
plt.title('Gráfico - Exercício 1')
plt.xticks(np.linspace(-40, 40, 5))
plt.yticks(np.linspace(-40, 80, 7))
plt.xlim(-55, 55)
plt.ylim(-55, 85)
plt.plot(x1, y1, 'blue');
plt.plot(x2, y2, 'blue');
plt.plot(x3, y3, 'blue');
plt.plot(x4, y4, 'blue');
plt.plot(x5, y5, 'blue');
plt.plot(x6, y6, 'blue');
plt.plot(x7, y7, 'blue');
plt.plot(x8, y8, 'blue')
plt.plot(xc8 - x8, y8, 'blue');

# %% [markdown]
# **EXERCÍCIO 2**

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

#variável de apoio para círculos e elipses
t = np.linspace(0, 2*np.pi, 100)

#circulo 1 - cabeça
r1 = 50
xc1, yc1 = 0, 0
x1 = r1 * np.cos(t) + xc1
y1 = r1 * np.sin(t) + yc1

#circulo 2 - orelha esquerda
r2 = 22
xc2, yc2 = -60, 40
x2 = r2 * np.cos(t) + xc2
y2 = r2 * np.sin(t) + yc2

#circulo 3  - orelha direita
r3 = 22
xc3, yc3 = 60, 40
x3 = r3 * np.cos(t) + xc3
y3 = r3 * np.sin(t) + yc3

#circulo 4  - olho esquerdo
r4 = 5
xc4, yc4 = -20, 10
x4 = r4 * np.cos(t) + xc4
y4 = r4 * np.sin(t) + yc4

#circulo 5  - olho direito
r5 = 5
xc5, yc5 = 20, 10
x5 = r5 * np.cos(t) + xc5
y5 = r5 * np.sin(t) + yc5

#elipse horizontal - nariz
a6 = 8
b6 = 4
xc6, yc6 = 0, -5
x6 = a6 * np.cos(t) + xc6
y6 = b6 * np.sin(t) + yc6

#elipse vertical 1 - olho esquerdo
a7 = 17
b7 = 8
xc7, yc7 = -20, 15
x7 = b7 * np.cos(t) + xc7
y7 = a7 * np.sin(t) + yc7

#elipse vertical 2 - olho direito
a8 = 17
b8 = 8
xc8, yc8 = 20, 15
x8 = b8 * np.cos(t) + xc8
y8 = a8 * np.sin(t) + yc8

#parábola 1 - boca
t9 = np.linspace(-40, 40,100)
a9 = 0.01
xv9, yv9 = 0,-25
x9 = t9
y9 = a9 * (t9 - xv9)**2 + yv9

#parábola 2 - boca
t10 = np.linspace(-20, 20,100)
a10 = 0.035
xv10, yv10 = 0,-35
x10 = t10
y10 = a10 * (t10 - xv10) ** 2 + yv10

#parábola 3 - boca
t11 = np.linspace(-20, 20,100)
a11 = -0.015
xv11, yv11 = 0, 0
x11 = t11
y11 = a11 * (t11 - xv11) ** 2 + yv11

#plotagem do gráfico
plt.figure(figsize=(14.4, 10.8))
plt.title('Gráfico - Exercício 2')
plt.xticks(np.linspace(-80, 80, 9))
plt.yticks(np.linspace(-40, 60, 6))
plt.xlim(-85, 85)
plt.ylim(-55, 65)
plt.plot(x1, y1, 'black');
plt.plot(x2, y2, 'black');
plt.plot(x3, y3, 'black');
plt.plot(x4, y4, 'black');
plt.plot(x5, y5, 'black');
plt.plot(x6, y6, 'black');
plt.plot(x7, y7, 'black');
plt.plot(x8, y8, 'black');
plt.plot(x9, y9, 'black');
plt.plot(x10, y10, 'black');
plt.plot(x11, y11, 'black');

# %% [markdown]
# **EXERCÍCIO 3**

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

#variável de apoio para círculos e elipses
tc = np.linspace(0, 2*np.pi, 100)

#circulo 1 - cabeça
r1 = 45
xc1, yc1 = 0, 15
x1 = r1 * np.cos(tc) + xc1
y1 = r1 * np.sin(tc) + yc1

#circulo 2 - olho direito
r2 = 8
xc2, yc2 = 10, 20
x2 = r2 * np.cos(tc) + xc2
y2 = r2 * np.sin(tc) + yc2

#circulo 3 - olho esquerdo
r3 = 8
xc3, yc3 = -10, 20
x3 = r3 * np.cos(tc) + xc3
y3 = r3 * np.sin(tc) + yc3

#elipse 1 horizontal - boca
a4 = 15
b4 = 7
xc4, yc4 = 0, -20
x4 = a4 * np.sin(tc) + xc4
y4 = b4 * np.cos(tc) + yc4

#elipse 2 vertical - olho esquerdo
a5 = 6
b5 = 0.5
xc5, yc5 = -10, 20
x5 = b5 * np.cos(tc) + xc5
y5 = a5 * np.sin(tc) + yc5

#elipse 3 vertical - olho direito
a6 = 6
b6 = 0.5
xc6, yc6 = 10, 20
x6 = b6 * np.cos(tc) + xc6
y6 = a6 * np.sin(tc) + yc6

#parábola 1 - sobrancelha esquerda
t7 = np.linspace(-20, 0, 100)
a7 = -0.08
xv7, yv7 = -10, 40
x7 = t7
y7 = a7 * (t7 - xv7) ** 2 + yv7

#parábola 2 - sobrancelha direita
t8 = np.linspace(0, 20, 100)
a8 = -0.08
xv8, yv8 = 10, 40
x8 = t8
y8 = a8 * (t8 - xv8) ** 2 + yv8

#variável de apoio para hipérboles
th = np.linspace(-3, 3, 100)

# hipérbole 1 - bigodes
a9 = 3
b9 = 0.2
xc9, yc9 = 0, 0
x9 = a9 * np.cosh(th) + xc9
y9 = b9 * np.sinh(th) + yc9

# hipérbole 2 - bigodes
a10 = 3
b10 = 0.5
xc10, yc10 = 0, 0
x10 = a10 * np.cosh(th) + xc10
y10 = b10 * np.sinh(th) + yc10

# hipérbole 3 - bigodes
a11 = 3
b11 = 1
xc11, yc11 = 0, 0
x11 = a11 * np.cosh(th) + xc11
y11 = b11 * np.sinh(th) + yc11

#semi-reta 1 - nariz
t12 = np.linspace(-5, 5, 100)
x12 = t12
y12 = 0 * x12 + 5

#rsemi-reta 2 - nariz
t13 = np.linspace(-5, 0, 100)
x13 = t13
y13 = -2 * x13 - 5

#semi-reta 3 - nariz
t14 = np.linspace(0, 5, 100)
x14 = t14
y14 = 2 * x14 - 5

#semi-reta 4 - orelha direita
t15 = np.linspace(10, 25, 100)
x15 = t15
y15 = 1.6 * x15 + 43

#semi-reta 5 - orelha direita
t16 = np.linspace(25, 40, 100)
x16 = t16
y16 = -3.13 * x16 + 161

#semi-reta 7 - orelha esquerda
t17 = np.linspace(-25, -10, 100)
x17 = t17
y17 = -1.6 * x17 + 43

#semi-reta 8 - orelha direita
t18 = np.linspace(-40, -25, 100)
x18 = t18
y18 = 3.13 * x18 + 161

#plotagem do gráfico
plt.figure(figsize=(13.75, 17.5))
plt.title('Gráfico - Exercício 3')
plt.xticks(np.linspace(-40, 40, 5))
plt.yticks(np.linspace(-40, 80, 7))
plt.xlim(-55, 55)
plt.ylim(-45, 85)
plt.plot(x1, y1, 'orange');
plt.plot(x2, y2, 'blue');
plt.plot(x3, y3, 'blue');
plt.plot(x4, y4, 'red');
plt.plot(x5, y5, 'black');
plt.plot(x6, y6, 'black');
plt.plot(x7, y7, 'orange');
plt.plot(x8, y8, 'orange');
plt.plot(x9, y9, 'black');
plt.plot(xc9 - x9, y9, 'black');
plt.plot(x10, y10, 'black');
plt.plot(xc10 - x10, y10, 'black');
plt.plot(x11, y11, 'black');
plt.plot(xc11 - x11, y11, 'black');
plt.plot(x12, y12, 'black');
plt.plot(x13, y13, 'black');
plt.plot(x14, y14, 'black');
plt.plot(x15, y15, 'orange');
plt.plot(x16, y16, 'orange');
plt.plot(x17, y17, 'orange');
plt.plot(x18, y18, 'orange');

# %% [markdown]
# **REFERÊNCIA**
#
# .
#
# Código original disponível em: https://github.com/otaviofernandes/Algebra_Linear/blob/main/AC2_Algebra_Linear.ipynb
